# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %%
df_wr = pd.read_csv('whale_returns.csv')
df_ar = pd.read_csv('algo_returns.csv')
df_sp = pd.read_csv('sp500_history.csv')

# %%
df_wr.head()
# Out:
#          Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0  2015-03-02                        NaN                 NaN
# 1  2015-03-03                  -0.001266           -0.004981
# 2  2015-03-04                   0.002230            0.003241
# 3  2015-03-05                   0.004016            0.004076
# 4  2015-03-06                  -0.007905           -0.003574
#
#    TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                          NaN                     NaN
# 1                    -0.000496               -0.006569
# 2                    -0.002534                0.004213
# 3                     0.002355                0.006726
# 4                    -0.008481               -0.013098

# %%
df_wr.set_index(pd.to_datetime(df_wr['Date'], infer_datetime_format=True), inplace=True)
df_wr = df_wr.drop(columns=['Date'])
df_wr
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# ...

# %%
df_wr.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
df_wr.dropna(inplace = True)

# %%
df_wr.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
df_wr.sort_index(inplace=True)

# %%
df_wr.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %%
df_ar.head()
# Out:
#          Date    Algo 1  Algo 2
# 0  2014-05-28  0.001745     NaN
# 1  2014-05-29  0.003978     NaN
# 2  2014-05-30  0.004464     NaN
# 3  2014-06-02  0.005692     NaN
# 4  2014-06-03  0.005292     NaN

# %%
df_ar.set_index(pd.to_datetime(df_ar['Date'], infer_datetime_format=True), inplace=True)
df_ar = df_ar.drop(columns=['Date'])
df_ar.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
df_ar.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
df_ar.dropna(inplace = True)

# %%
df_ar.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
df_ar.sort_index(inplace=True)

# %%
df_ar.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %%
df_sp.head()
# Out:
#         Date     Close
# 0  23-Apr-19  $2933.68
# 1  22-Apr-19  $2907.97
# 2  18-Apr-19  $2905.03
# 3  17-Apr-19  $2900.45
# 4  16-Apr-19  $2907.06

# %%
df_sp.set_index(pd.to_datetime(df_sp['Date'], infer_datetime_format=True), inplace=True)
df_sp = df_sp.drop(columns=['Date'])
df_sp.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
df_sp.dtypes
# Out:
# Close    object
# dtype: object

# %%
df_sp['Close'] = df_sp['Close'].str.replace('$','')

# %%
df_sp.head()
# Out:
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75
# 2012-10-03  1450.99
# 2012-10-04  1461.40
# 2012-10-05  1460.93

# %%
df_sp.sort_index(inplace=True)

# %%
df_sp.head()
# Out:
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75
# 2012-10-03  1450.99
# 2012-10-04  1461.40
# 2012-10-05  1460.93

# %%
df_sp['Close'] = df_sp['Close'].astype(float)

# %%
df_sp.dtypes
# Out:
# Close    float64
# dtype: object

# %%
df_spreturn = df_sp.pct_change()

# %%
df_spreturn.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
df_spreturn.dropna(inplace=True)

# %%
df_spreturn.head()
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
df_spreturn.columns = ['S&P 500']

# %%
df_spreturn.head()
# Out:
#              S&P 500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
df = pd.concat([df_wr, df_ar, df_spreturn], axis="columns", join="inner")

# %%
df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-02                          NaN                     NaN -0.008158
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
#
#               Algo 2   S&P 500
# Date
# 2015-03-02  0.003200  0.006125
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# ...

# %%
df.plot(figsize=(30,10))

# %%
df_cumreturn = (1+ df).cumprod()-1

# %%
df_cumreturn.plot(figsize=(30,10))

# %%
df.boxplot(figsize=(30,10))

# %%
df_std = df.std()

# %%
df_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007621
# Algo 2                         0.008339
# S&P 500                        0.008551
# dtype: float64

# %%
print(df_std > df_std.at['S&P 500'])
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# S&P 500                        False
# dtype: bool

# %%
df_annualized_std = df_std * np.sqrt(252)

# %%
df_annualized_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120987
# Algo 2                         0.132374
# S&P 500                        0.135751
# dtype: float64

# %%
df_correlation = df.corr()

# %%
df_correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P 500                                       0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# ...

# %%
 Cov = df['Algo 1'].cov(df['S&P 500'])

# %%
Cov
# Out:
# 1.81514913779677e-05

# %%
Var = df['Algo 1'].var()

# %%
Algo1_Beta = Cov / Var

# %%
Algo1_Beta
# Out:
# 0.31249172356217114

# %%
Rolling_Cov = df['Algo 1'].rolling(window = 21).cov(df['S&P 500'])

# %%
Rolling_Cov.plot(figsize=(30,10))

# %%
df_sharpe = (df.mean() * 252) / (df.std() * np.sqrt(252))

# %%
df_sharpe
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.360829
# Algo 2                         0.506929
# S&P 500                        0.658706
# dtype: float64

# %%
df_sharpe.plot(kind="bar")

# %%
# We can see that the Sharpe Ratio of Algo 1 is the highest in the portfolio indicates that the Risk and Return for Algo 1 is better than the rest

# %%
df_mia = pd.read_csv('mia_portfolio.csv')

# %%
df_mia.head()
# Out:
#        Date      F   SOL   REDU
# 0  3/2/2015  16.57  6.85  16.61
# 1  3/3/2015  16.17  6.75  15.14
# 2  3/4/2015  16.03  7.15  14.27
# 3  3/5/2015  16.11  8.15  12.21
# 4  3/6/2015  15.93  7.70  12.30

# %%
df_mia['Date']= pd.to_datetime(df_mia['Date'])

# %%
df_mia.head()
# Out:
#         Date      F   SOL   REDU
# 0 2015-03-02  16.57  6.85  16.61
# 1 2015-03-03  16.17  6.75  15.14
# 2 2015-03-04  16.03  7.15  14.27
# 3 2015-03-05  16.11  8.15  12.21
# 4 2015-03-06  15.93  7.70  12.30

# %%
df_mia.set_index(pd.to_datetime(df_mia['Date'], infer_datetime_format=True), inplace=True)

# %%
df_mia.head()
# Out:
#                  Date      F   SOL   REDU
# Date
# 2015-03-02 2015-03-02  16.57  6.85  16.61
# 2015-03-03 2015-03-03  16.17  6.75  15.14
# 2015-03-04 2015-03-04  16.03  7.15  14.27
# 2015-03-05 2015-03-05  16.11  8.15  12.21
# 2015-03-06 2015-03-06  15.93  7.70  12.30

# %%
df_mia = df_mia.drop(columns=['Date'])

# %%
df_mia.head()
# Out:
#                 F   SOL   REDU
# Date
# 2015-03-02  16.57  6.85  16.61
# 2015-03-03  16.17  6.75  15.14
# 2015-03-04  16.03  7.15  14.27
# 2015-03-05  16.11  8.15  12.21
# 2015-03-06  15.93  7.70  12.30

# %%
df_mia = df_mia.pct_change()

# %%
df_mia.head()
# Out:
#                    F       SOL      REDU
# Date
# 2015-03-02       NaN       NaN       NaN
# 2015-03-03 -0.024140 -0.014599 -0.088501
# 2015-03-04 -0.008658  0.059259 -0.057464
# 2015-03-05  0.004991  0.139860 -0.144359
# 2015-03-06 -0.011173 -0.055215  0.007371

# %%
df_mia.dropna(inplace=True)

# %%
df_mia.head()
# Out:
#                    F       SOL      REDU
# Date
# 2015-03-03 -0.024140 -0.014599 -0.088501
# 2015-03-04 -0.008658  0.059259 -0.057464
# 2015-03-05  0.004991  0.139860 -0.144359
# 2015-03-06 -0.011173 -0.055215  0.007371
# 2015-03-09  0.006277 -0.064935  0.117073

# %%
weights = [.3,.3,.4]

# %%
df_mia = df_mia.dot(weights)

# %%
df_mia.head()
# Out:
# Date
# 2015-03-03   -0.047022
# 2015-03-04   -0.007805
# 2015-03-05   -0.014288
# 2015-03-06   -0.016968
# 2015-03-09    0.029232
# dtype: float64

# %%
df_mia = pd.DataFrame(df_mia)

# %%
df_mia
# Out:
#                    0
# Date
# 2015-03-03 -0.047022
# 2015-03-04 -0.007805
# 2015-03-05 -0.014288
# 2015-03-06 -0.016968
# 2015-03-09  0.029232
# ...              ...
# 2019-09-23  0.002864
# 2019-09-24 -0.017427
# 2019-09-25  0.002964
# 2019-09-26 -0.011957
# 2019-09-27 -0.029556
#
# [1153 rows x 1 columns]

# %%
df_mia.columns = ['Mia Portfolio']

# %%
df_mia.head()
# Out:
#             Mia Portfolio
# Date
# 2015-03-03      -0.047022
# 2015-03-04      -0.007805
# 2015-03-05      -0.014288
# 2015-03-06      -0.016968
# 2015-03-09       0.029232

# %%
df2 = pd.concat([df, df_mia], axis="columns", join="inner")

# %%
df2.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500  Mia Portfolio
# Date
# 2015-03-03 -0.000949 -0.004539      -0.047022
# 2015-03-04  0.002416 -0.004389      -0.007805
# ...

# %%
df2.dropna(inplace=True)

# %%
df2_std = df2.std()

# %%
df2_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# S&P 500                        0.008554
# Mia Portfolio                  0.015388
# dtype: float64

# %%
print(df2_std > df2_std.at['S&P 500'])
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# S&P 500                        False
# Mia Portfolio                   True
# dtype: bool

# %%
df2_21days_std = df2_std * np.sqrt(21)

# %%
df2_21days_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.036181
# PAULSON & CO.INC.              0.032184
# TIGER GLOBAL MANAGEMENT LLC    0.049922
# BERKSHIRE HATHAWAY INC         0.059201
# Algo 1                         0.034920
# Algo 2                         0.038229
# S&P 500                        0.039198
# Mia Portfolio                  0.070515
# dtype: float64

# %%
df2.rolling(window=21).std().plot(figsize=(30,10))

# %%
df2_correlation = df2.corr()
df2_correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P 500                                       0.837864            0.669732
# Mia Portfolio                                 0.356460            0.255960
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# ...

# %%
df2_sharpe = (df2.mean() * 252) / (df2.std() * np.sqrt(252))

# %%
df2_sharpe
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# S&P 500                        0.648267
# Mia Portfolio                 -0.492130
# dtype: float64

# %%
df2_sharpe.plot(kind='bar')

# %%
Rolling_Cov2 = df2['Mia Portfolio'].rolling(window = 21).cov(df2['S&P 500'])

# %%
Rolling_Cov2.plot(figsize=(30,10))

# %%
Cov2 = df2['Mia Portfolio'].cov(df2['S&P 500'])

# %%
Var2 = df2['Mia Portfolio'].var()

# %%
Mia_Beta = Cov2 / Var2

# %%
Mia_Beta
# Out:
# 0.21065777199693447
